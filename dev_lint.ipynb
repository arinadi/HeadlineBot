# %% [markdown]
# # 🛠️ HeadlineBot — Lint & Auto-fix
# Clone or pull, then run lint.

# %%
import os
if os.path.exists('HeadlineBot'):
    # %cd HeadlineBot
    # !git pull
else:
    # !git clone https://github.com/arinadi/HeadlineBot.git
    # %cd HeadlineBot
# !pip install ruff -q
# !ruff check . --fix --output-format=concise
